# %%
import sys

import matplotlib.pyplot as plt
import missingno as msno
import numpy as np
import pandas as pd

print('python:'.ljust(16), sys.version.split('\n')[0])
# Out:
# python:          3.8.9 (default, Apr 13 2022, 08:48:06)

# %% [markdown]
# ## Define constants

# %%
DATA_PATH = './data/'

TARGET = 'is_bad'  # Target feature
TRAIN = 'TRAIN'  # Binary feature to separate train and valid data

# %% [markdown]
# ## Load data

# %%
# Load datasets
df_train = pd.read_csv(DATA_PATH + 'train.csv', parse_dates=['datetime_submitted'])
df_valid = pd.read_csv(DATA_PATH + 'val.csv', parse_dates=['datetime_submitted'])

# Join train and valid datasets
df_train[TRAIN] = True  # Train/valid flag
df_valid[TRAIN] = False  # Train/valid flag
df = pd.concat([df_train, df_valid], ignore_index=True)

del df_train
del df_valid

# %% [markdown]
# ## View df general info

# %%
df
# Out:
#                                            title  \
# 0                                  Диван-кровать
# 1        Кожух рулевой колонки Даф хф 91 4509834
# 2                  Дешёвый буст аккаунтов Dota 4
# 3              Телевизор sharp.Смарт тв.Интернет
# 4                               Открытка-конверт
# ...                                          ...
# 1000719                        Офисное помещение
# 1000720                iPhone 8 Plus Silver 25GB
# 1000721             6-к квартира, 54 м², 5/9 эт.
# 1000722             4-к квартира, 60 м², 9/9 эт.
# 1000723                        BMW 7 серия, 1031
#
#                                                description  \
# 0        Продаем диван-кровать. Удобный механизм - евро...
# 1        Кожух рулевой колонки DAF XF 94 (60066004)/\n ...
# 2        ! Буст аккаунтов с ммр выше 1000ммр не беру ! ...
# 3        Продам телевизор . Диагональ 450.наличие входа...
# 4        Открытки-конверты ручной работы/\nВыполнены в ...
# ...                                                    ...
# 1000719  Сдаются офисное помещение по Ул Калинина 80. П...
# 1000720  Оригинальный ростест айфон. Идеальное состояни...
# 1000721  ______________________________________________...
# 1000722   /\n /\n● Работаем БЕЗ ПЕРЕРЫВОВ И ВЫХОДНЫХ с ...
# 1000723  Машина технически в отличном состояние все сис...
#
#                        subcategory             category      price  \
# 0                Мебель и интерьер      Для дома и дачи     7000.0
# 1            Запчасти и аксессуары            Транспорт     2290.0
# 2                Предложение услуг               Услуги      200.0
# 3                    Аудио и видео  Бытовая электроника    25000.0
# 4               Коллекционирование        Хобби и отдых      150.0
# ...                            ...                  ...        ...
# 1000719  Коммерческая недвижимость         Недвижимость     9200.0
# 1000720                   Телефоны  Бытовая электроника    20000.0
# 1000721                   Квартиры         Недвижимость  3300000.0
# 1000722                   Квартиры         Недвижимость  2300000.0
# 1000723                 Автомобили            Транспорт  1550000.0
#
#                           region             city         datetime_submitted  \
# 0                         Россия           Москва 2019-06-01 00:00:15.180656
# 1                         Россия           Москва 2019-06-01 00:00:44.317933
# 2                Северная Осетия      Владикавказ 2019-06-01 00:00:50.249692
# 3        Калининградская область          Советск 2019-06-01 00:00:50.325799
# 4            Ставропольский край     Ессентукская 2019-06-01 00:00:56.632655
# ...                          ...              ...                        ...
# 1000719                  Чувашия        Чебоксары 2019-10-14 23:57:30.094904
# 1000720                Татарстан           Казань 2019-10-14 23:57:50.610616
# 1000721      Ставропольский край        Пятигорск 2019-10-14 23:58:02.781579
# 1000722      Ставропольский край        Пятигорск 2019-10-14 23:59:01.435691
# 1000723    Нижегородская область  Нижний Новгород 2019-10-14 23:59:31.048375
#
#          is_bad  TRAIN
# 0             0   True
# 1             0   True
# 2             1   True
# 3             1   True
# 4             0   True
# ...         ...    ...
# 1000719       0  False
# 1000720       0  False
# 1000721       0  False
# 1000722       0  False
# 1000723       1  False
#
# [1000724 rows x 10 columns]

# %%
df.loc[df[TRAIN]].info()
print()
df.loc[~df[TRAIN]].info()
print()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 984487 entries, 0 to 984486
# Data columns (total 10 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   title               984487 non-null  object
#  1   description         984487 non-null  object
#  2   subcategory         984487 non-null  object
#  3   category            984487 non-null  object
#  4   price               926439 non-null  float64
#  5   region              984487 non-null  object
#  6   city                984487 non-null  object
#  7   datetime_submitted  984487 non-null  datetime64[ns]
#  8   is_bad              984487 non-null  int64
#  9   TRAIN               984487 non-null  bool
# dtypes: bool(1), datetime64[ns](1), float64(1), int64(1), object(6)
# memory usage: 76.0+ MB
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16237 entries, 984487 to 1000723
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   title               16237 non-null  object
#  1   description         16237 non-null  object
#  2   subcategory         16237 non-null  object
#  3   category            16237 non-null  object
#  4   price               15374 non-null  float64
#  5   region              16237 non-null  object
#  6   city                16237 non-null  object
#  7   datetime_submitted  16237 non-null  datetime64[ns]
#  8   is_bad              16237 non-null  int64
#  9   TRAIN               16237 non-null  bool
# dtypes: bool(1), datetime64[ns](1), float64(1), int64(1), object(6)
# memory usage: 1.3+ MB
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000724 entries, 0 to 1000723
# Data columns (total 10 columns):
#  #   Column              Non-Null Count    Dtype
# ---  ------              --------------    -----
#  0   title               1000724 non-null  object
#  1   description         1000724 non-null  object
#  2   subcategory         1000724 non-null  object
#  3   category            1000724 non-null  object
#  4   price               941813 non-null   float64
#  5   region              1000724 non-null  object
#  6   city                1000724 non-null  object
#  7   datetime_submitted  1000724 non-null  datetime64[ns]
#  8   is_bad              1000724 non-null  int64
#  9   TRAIN               1000724 non-null  bool
# dtypes: bool(1), datetime64[ns](1), float64(1), int64(1), object(6)
# memory usage: 69.7+ MB

# %%
msno.matrix(df);

# %% [markdown]
# ## View historgams

# %%
fig, axes = plt.subplots(figsize=(16, 6), nrows=1, ncols=2)
df.loc[df[TRAIN], 'datetime_submitted'].hist(bins=100, ax=axes[0])
df.loc[~df[TRAIN], 'datetime_submitted'].hist(bins=100, ax=axes[1])
axes[0].set_title('Training datetime_submitted distr.')
axes[1].set_title('Validation datetime_submitted distr.')
plt.show()

# %%
df.loc[df['price'] <= 50000, 'price'].hist(bins=50)
plt.title('Price distribution');

# %%
bins = 500
df.loc[df['price'] <= bins*100, 'price'].plot(kind='hist', bins=bins, logy=True, figsize=(16,8))
plt.title('Log price distribution');

# %% [markdown]
# ## View category distribution

# %%
for column in ['is_bad', 'category', 'subcategory', 'region', 'city']:
    print('Number of unique         :', df[column].unique().shape[0])
    print('Number of unique in TRAIN:', df.loc[df[TRAIN], column].unique().shape[0])
    df[column].value_counts().iloc[:85].plot.bar(figsize=(16, 6), title=column)
    plt.show()
    print()
# Out:
# Number of unique         : 2
# Number of unique in TRAIN: 2
# Number of unique         : 10
# Number of unique in TRAIN: 10
# Number of unique         : 50
# Number of unique in TRAIN: 50
# Number of unique         : 85
# Number of unique in TRAIN: 85
# Number of unique         : 3311
# Number of unique in TRAIN: 3311
